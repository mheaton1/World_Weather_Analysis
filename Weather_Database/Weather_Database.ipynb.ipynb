# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 777

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = 'https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=' + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        lat=city_weather["coord"]["lat"]
        lng=city_weather["coord"]["lon"]
        max_temp=city_weather["main"]["temp_max"]
        humidity=city_weather["main"]["humidity"]
        cloudiness=city_weather["clouds"]["all"]
        wind=city_weather["wind"]["speed"]
        country=city_weather["sys"]["country"]
        description=city_weather["weather"][0]["description"]      
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": lat,
                          "Lng": lng,
                          "Max Temp": max_temp,
                          "Humidity": humidity,
                          "Cloudiness": cloudiness,
                          "Wind Speed": wind,
                          "Country": country,
                          "Current Description": description
                         })
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mangalia
# Processing Record 2 of Set 1 | hilo
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | souillac
# Processing Record 5 of Set 1 | saint-philippe
# Processing Record 6 of Set 1 | nanortalik
# Processing Record 7 of Set 1 | arraial do cabo
# Processing Record 8 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | khatanga
# Processing Record 11 of Set 1 | mattru
# Processing Record 12 of Set 1 | hobart
# Processing Record 13 of Set 1 | tuatapere
# Processing Record 14 of Set 1 | bethel
# Processing Record 15 of Set 1 | dong hoi
# Processing Record 16 of Set 1 | ribeira grande
# Processing Record 17 of Set 1 | hualmay
# Processing Record 18 of Set 1 | chokurdakh
# Processing Record 19 of Set 1 | cidreira
# Processing Record 20 of Set 1 | salekhard
# Processing Record 21 of Set 1 | severo-kurilsk
# Processing Record 22 of Set 1 | perene
# Processing Record 23 of Set 1 | qaanaaq
# Processing Record 24 of Set 1 | ulladulla
# Processing Record 25 of Set 1 | jinchang
# Processing Record 26 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 1 | dingle
# Processing Record 28 of Set 1 | avera
# Processing Record 29 of Set 1 | cabra
# Processing Record 30 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 1 | yar-sale
# Processing Record 32 of Set 1 | punta arenas
# Processing Record 33 of Set 1 | ostrovnoy
# Processing Record 34 of Set 1 | provideniya
# Processing Record 35 of Set 1 | carnarvon
# Processing Record 36 of Set 1 | atuona
# Processing Record 37 of Set 1 | alta floresta
# Processing Record 38 of Set 1 | tefe
# Processing Record 39 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 1 | butaritari
# Processing Record 41 of Set 1 | aquiraz
# Processing Record 42 of Set 1 | miraflores
# Processing Record 43 of Set 1 | ancud
# Processing Record 44 of Set 1 | beringovskiy
# Processing Record 45 of Set 1 | longyearbyen
# Processing Record 46 of Set 1 | vaini
# Processing Record 47 of Set 1 | lucea
# Processing Record 48 of Set 1 | tucuma
# Processing Record 49 of Set 1 | saskylakh
# Processing Record 50 of Set 1 | chateaubelair
# Processing Record 1 of Set 2 | ushuaia
# Processing Record 2 of Set 2 | raudeberg
# Processing Record 3 of Set 2 | develi
# Processing Record 4 of Set 2 | nikolskoye
# Processing Record 5 of Set 2 | lakatoro
# Processing Record 6 of Set 2 | moron
# Processing Record 7 of Set 2 | thompson
# Processing Record 8 of Set 2 | woodstock
# Processing Record 9 of Set 2 | victoria
# Processing Record 10 of Set 2 | manzhouli
# Processing Record 11 of Set 2 | bluff
# Processing Record 12 of Set 2 | port alfred
# Processing Record 13 of Set 2 | north bend
# Processing Record 14 of Set 2 | avarua
# Processing Record 15 of Set 2 | treinta y tres
# Processing Record 16 of Set 2 | lynn haven
# Processing Record 17 of Set 2 | tiksi
# Processing Record 18 of Set 2 | coahuayana
# Processing Record 19 of Set 2 | castro
# Processing Record 20 of Set 2 | shelburne
# Processing Record 21 of Set 2 | weligama
# Processing Record 22 of Set 2 | rikitea
# Processing Record 23 of Set 2 | knysna
# Processing Record 24 of Set 2 | christchurch
# Processing Record 25 of Set 2 | tilichiki
# Processing Record 26 of Set 2 | port elizabeth
# Processing Record 27 of Set 2 | catio
# Processing Record 28 of Set 2 | baraboo
# Processing Record 29 of Set 2 | mahebourg
# Processing Record 30 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 2 | san ignacio
# Processing Record 34 of Set 2 | tautira
# Processing Record 35 of Set 2 | neuquen
# Processing Record 36 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 37 of Set 2 | lebanon
# Processing Record 38 of Set 2 | yellowknife
# Processing Record 39 of Set 2 | hithadhoo
# Processing Record 40 of Set 2 | rincon de la victoria
# Processing Record 41 of Set 2 | tuktoyaktuk
# Processing Record 42 of Set 2 | bredasdorp
# Processing Record 43 of Set 2 | gao
# Processing Record 44 of Set 2 | huilong
# Processing Record 45 of Set 2 | cape town
# Processing Record 46 of Set 2 | dikson
# Processing Record 47 of Set 2 | barrow
# Processing Record 48 of Set 2 | makat
# Processing Record 49 of Set 2 | naze
# Processing Record 50 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 3 | sorong
# Processing Record 2 of Set 3 | fortuna
# Processing Record 3 of Set 3 | airai
# Processing Record 4 of Set 3 | west monroe
# Processing Record 5 of Set 3 | new norfolk
# Processing Record 6 of Set 3 | cairns
# Processing Record 7 of Set 3 | cayenne
# Processing Record 8 of Set 3 | muravlenko
# Processing Record 9 of Set 3 | tomatlan
# Processing Record 10 of Set 3 | jamestown
# Processing Record 11 of Set 3 | geraldton
# Processing Record 12 of Set 3 | saint george
# Processing Record 13 of Set 3 | tuy hoa
# Processing Record 14 of Set 3 | hermanus
# Processing Record 15 of Set 3 | sitka
# Processing Record 16 of Set 3 | bonavista
# Processing Record 17 of Set 3 | tucuman
# Processing Record 18 of Set 3 | chicama
# Processing Record 19 of Set 3 | camargo
# Processing Record 20 of Set 3 | puerto ayora
# Processing Record 21 of Set 3 | rialma
# Processing Record 22 of Set 3 | bambous virieux
# Processing Record 23 of Set 3 | santa cruz
# Processing Record 24 of Set 3 | tungor
# Processing Record 25 of Set 3 | palmer
# Processing Record 26 of Set 3 | karratha
# Processing Record 27 of Set 3 | nenjiang
# Processing Record 28 of Set 3 | tequixquitla
# Processing Record 29 of Set 3 | dunedin
# Processing Record 30 of Set 3 | pevek
# Processing Record 31 of Set 3 | hasaki
# Processing Record 32 of Set 3 | waipawa
# Processing Record 33 of Set 3 | narsaq
# Processing Record 34 of Set 3 | kaitangata
# Processing Record 35 of Set 3 | sur
# Processing Record 36 of Set 3 | fort saint john
# City not found. Skipping...
# Processing Record 37 of Set 3 | asau
# Processing Record 38 of Set 3 | ossora
# Processing Record 39 of Set 3 | dawlatabad
# Processing Record 40 of Set 3 | itarema
# Processing Record 41 of Set 3 | pemangkat
# Processing Record 42 of Set 3 | karatau
# Processing Record 43 of Set 3 | ambilobe
# Processing Record 44 of Set 3 | nome
# Processing Record 45 of Set 3 | upernavik
# Processing Record 46 of Set 3 | mount isa
# Processing Record 47 of Set 3 | lat yao
# Processing Record 48 of Set 3 | zhoucheng
# Processing Record 49 of Set 3 | port lincoln
# Processing Record 50 of Set 3 | chipinge
# Processing Record 1 of Set 4 | conde
# Processing Record 2 of Set 4 | kavieng
# Processing Record 3 of Set 4 | ponferrada
# Processing Record 4 of Set 4 | letka
# Processing Record 5 of Set 4 | yeppoon
# Processing Record 6 of Set 4 | troitsko-pechorsk
# Processing Record 7 of Set 4 | nagato
# Processing Record 8 of Set 4 | igrim
# Processing Record 9 of Set 4 | kimbe
# Processing Record 10 of Set 4 | lebu
# Processing Record 11 of Set 4 | cabo san lucas
# Processing Record 12 of Set 4 | olafsvik
# Processing Record 13 of Set 4 | faya
# Processing Record 14 of Set 4 | palauig
# Processing Record 15 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 4 | sabang
# Processing Record 17 of Set 4 | noumea
# Processing Record 18 of Set 4 | inhambane
# Processing Record 19 of Set 4 | lyubuchany
# Processing Record 20 of Set 4 | sao filipe
# Processing Record 21 of Set 4 | vernon
# Processing Record 22 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 4 | praya
# Processing Record 24 of Set 4 | esperance
# Processing Record 25 of Set 4 | ilulissat
# Processing Record 26 of Set 4 | cedar city
# Processing Record 27 of Set 4 | tall kayf
# Processing Record 28 of Set 4 | balkhash
# Processing Record 29 of Set 4 | te anau
# Processing Record 30 of Set 4 | deh rawud
# City not found. Skipping...
# Processing Record 31 of Set 4 | rehoboth
# Processing Record 32 of Set 4 | adelaide
# Processing Record 33 of Set 4 | alice springs
# Processing Record 34 of Set 4 | vila franca do campo
# Processing Record 35 of Set 4 | margate
# Processing Record 36 of Set 4 | algiers
# Processing Record 37 of Set 4 | saldanha
# Processing Record 38 of Set 4 | sahuaripa
# Processing Record 39 of Set 4 | nantucket
# Processing Record 40 of Set 4 | general roca
# Processing Record 41 of Set 4 | slave lake
# Processing Record 42 of Set 4 | ishigaki
# Processing Record 43 of Set 4 | zhigansk
# Processing Record 44 of Set 4 | huntsville
# Processing Record 45 of Set 4 | kapit
# Processing Record 46 of Set 4 | kamaishi
# Processing Record 47 of Set 4 | rio gallegos
# Processing Record 48 of Set 4 | ust-nera
# Processing Record 49 of Set 4 | kapaa
# Processing Record 50 of Set 4 | makubetsu
# Processing Record 1 of Set 5 | ozgon
# City not found. Skipping...
# Processing Record 2 of Set 5 | fevik
# Processing Record 3 of Set 5 | katsuura
# Processing Record 4 of Set 5 | gladstone
# Processing Record 5 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 5 | leningradskiy
# Processing Record 7 of Set 5 | ponta delgada
# Processing Record 8 of Set 5 | laguna
# Processing Record 9 of Set 5 | russkaya polyana
# Processing Record 10 of Set 5 | esil
# Processing Record 11 of Set 5 | galgani
# City not found. Skipping...
# Processing Record 12 of Set 5 | pisco
# Processing Record 13 of Set 5 | luanda
# Processing Record 14 of Set 5 | nalut
# Processing Record 15 of Set 5 | lavrentiya
# Processing Record 16 of Set 5 | sapao
# City not found. Skipping...
# Processing Record 17 of Set 5 | oranjemund
# Processing Record 18 of Set 5 | majene
# Processing Record 19 of Set 5 | douglas
# Processing Record 20 of Set 5 | najran
# Processing Record 21 of Set 5 | fallon
# Processing Record 22 of Set 5 | torrox
# Processing Record 23 of Set 5 | kalmunai
# Processing Record 24 of Set 5 | nizhnevartovsk
# Processing Record 25 of Set 5 | mocambique
# City not found. Skipping...
# Processing Record 26 of Set 5 | klaksvik
# Processing Record 27 of Set 5 | gornozavodsk
# Processing Record 28 of Set 5 | zhuanghe
# Processing Record 29 of Set 5 | tairua
# Processing Record 30 of Set 5 | clyde river
# Processing Record 31 of Set 5 | kahului
# Processing Record 32 of Set 5 | ulaanbaatar
# Processing Record 33 of Set 5 | caravelas
# Processing Record 34 of Set 5 | coihaique
# Processing Record 35 of Set 5 | uvat
# Processing Record 36 of Set 5 | kodiak
# Processing Record 37 of Set 5 | quatre cocos
# Processing Record 38 of Set 5 | isangel
# Processing Record 39 of Set 5 | mahibadhoo
# Processing Record 40 of Set 5 | ullapool
# Processing Record 41 of Set 5 | savannah bight
# Processing Record 42 of Set 5 | azanka
# Processing Record 43 of Set 5 | havelock
# Processing Record 44 of Set 5 | broken hill
# Processing Record 45 of Set 5 | busselton
# Processing Record 46 of Set 5 | fairbanks
# Processing Record 47 of Set 5 | mar del plata
# Processing Record 48 of Set 5 | caohe
# Processing Record 49 of Set 5 | celestun
# Processing Record 50 of Set 5 | san patricio
# Processing Record 1 of Set 6 | ust-kishert
# Processing Record 2 of Set 6 | rawah
# Processing Record 3 of Set 6 | snasa
# Processing Record 4 of Set 6 | lulea
# Processing Record 5 of Set 6 | agadez
# Processing Record 6 of Set 6 | miri
# Processing Record 7 of Set 6 | merrill
# Processing Record 8 of Set 6 | paamiut
# Processing Record 9 of Set 6 | olinda
# Processing Record 10 of Set 6 | pochutla
# Processing Record 11 of Set 6 | havoysund
# Processing Record 12 of Set 6 | cap malheureux
# Processing Record 13 of Set 6 | calama
# Processing Record 14 of Set 6 | talnakh
# Processing Record 15 of Set 6 | nishihara
# Processing Record 16 of Set 6 | batangafo
# Processing Record 17 of Set 6 | bengkulu
# Processing Record 18 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 6 | morondava
# Processing Record 20 of Set 6 | stoyba
# City not found. Skipping...
# Processing Record 21 of Set 6 | nosy varika
# Processing Record 22 of Set 6 | codrington
# Processing Record 23 of Set 6 | rundu
# Processing Record 24 of Set 6 | ayan
# Processing Record 25 of Set 6 | luwuk
# Processing Record 26 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 27 of Set 6 | georgetown
# Processing Record 28 of Set 6 | bafq
# Processing Record 29 of Set 6 | humboldt
# Processing Record 30 of Set 6 | camana
# Processing Record 31 of Set 6 | vardo
# Processing Record 32 of Set 6 | opuwo
# Processing Record 33 of Set 6 | faanui
# Processing Record 34 of Set 6 | dankov
# Processing Record 35 of Set 6 | pacific grove
# Processing Record 36 of Set 6 | ouadda
# Processing Record 37 of Set 6 | palmas bellas
# Processing Record 38 of Set 6 | kibala
# Processing Record 39 of Set 6 | bajos de haina
# Processing Record 40 of Set 6 | kisangani
# Processing Record 41 of Set 6 | aykhal
# Processing Record 42 of Set 6 | svetlogorsk
# Processing Record 43 of Set 6 | omboue
# Processing Record 44 of Set 6 | veraval
# Processing Record 45 of Set 6 | meadow lake
# Processing Record 46 of Set 6 | katsuyama
# Processing Record 47 of Set 6 | bialystok
# Processing Record 48 of Set 6 | iqaluit
# Processing Record 49 of Set 6 | muros
# Processing Record 50 of Set 6 | kulevcha
# Processing Record 1 of Set 7 | cascais
# Processing Record 2 of Set 7 | huarmey
# Processing Record 3 of Set 7 | kyzyl-suu
# Processing Record 4 of Set 7 | zeya
# Processing Record 5 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 7 | tornio
# Processing Record 7 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 7 | morros
# Processing Record 9 of Set 7 | batagay
# Processing Record 10 of Set 7 | lata
# Processing Record 11 of Set 7 | saurimo
# Processing Record 12 of Set 7 | muisne
# Processing Record 13 of Set 7 | ende
# Processing Record 14 of Set 7 | tasiilaq
# Processing Record 15 of Set 7 | lagoa
# Processing Record 16 of Set 7 | marawi
# Processing Record 17 of Set 7 | taoudenni
# Processing Record 18 of Set 7 | pangnirtung
# Processing Record 19 of Set 7 | tupik
# Processing Record 20 of Set 7 | arman
# Processing Record 21 of Set 7 | bandar-e lengeh
# Processing Record 22 of Set 7 | saryshagan
# City not found. Skipping...
# Processing Record 23 of Set 7 | biak
# Processing Record 24 of Set 7 | sambava
# Processing Record 25 of Set 7 | komatipoort
# Processing Record 26 of Set 7 | ust-kuyga
# Processing Record 27 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 28 of Set 7 | mahadday weyne
# City not found. Skipping...
# Processing Record 29 of Set 7 | severo-yeniseyskiy
# Processing Record 30 of Set 7 | mount gambier
# Processing Record 31 of Set 7 | lanigan
# Processing Record 32 of Set 7 | baruun-urt
# Processing Record 33 of Set 7 | ponta do sol
# Processing Record 34 of Set 7 | east london
# Processing Record 35 of Set 7 | powell
# Processing Record 36 of Set 7 | sakakah
# Processing Record 37 of Set 7 | camapua
# Processing Record 38 of Set 7 | novyy buyan
# Processing Record 39 of Set 7 | lompoc
# Processing Record 40 of Set 7 | vrangel
# Processing Record 41 of Set 7 | sozimskiy
# Processing Record 42 of Set 7 | wanning
# Processing Record 43 of Set 7 | dukat
# Processing Record 44 of Set 7 | muscat
# Processing Record 45 of Set 7 | kondinskoye
# Processing Record 46 of Set 7 | hillsboro
# Processing Record 47 of Set 7 | tura
# Processing Record 48 of Set 7 | ahuimanu
# Processing Record 49 of Set 7 | dickinson
# Processing Record 50 of Set 7 | ondorhaan
# City not found. Skipping...
# Processing Record 1 of Set 8 | kapoeta
# Processing Record 2 of Set 8 | mehamn
# Processing Record 3 of Set 8 | terrace bay
# Processing Record 4 of Set 8 | torbay
# Processing Record 5 of Set 8 | pathein
# Processing Record 6 of Set 8 | wenatchee
# Processing Record 7 of Set 8 | gat
# Processing Record 8 of Set 8 | maroantsetra
# Processing Record 9 of Set 8 | pitimbu
# Processing Record 10 of Set 8 | henties bay
# Processing Record 11 of Set 8 | marv dasht
# City not found. Skipping...
# Processing Record 12 of Set 8 | birjand
# Processing Record 13 of Set 8 | andevoranto
# City not found. Skipping...
# Processing Record 14 of Set 8 | port hardy
# Processing Record 15 of Set 8 | abu dhabi
# Processing Record 16 of Set 8 | matagami
# Processing Record 17 of Set 8 | chippewa falls
# Processing Record 18 of Set 8 | sao joao da barra
# Processing Record 19 of Set 8 | berlevag
# Processing Record 20 of Set 8 | semirara
# Processing Record 21 of Set 8 | griffith
# Processing Record 22 of Set 8 | soyo
# Processing Record 23 of Set 8 | nova odesa
# Processing Record 24 of Set 8 | verkhnevilyuysk
# Processing Record 25 of Set 8 | vestmannaeyjar
# Processing Record 26 of Set 8 | roald
# Processing Record 27 of Set 8 | zarate
# Processing Record 28 of Set 8 | san-pedro
# Processing Record 29 of Set 8 | qaqortoq
# Processing Record 30 of Set 8 | kangundo
# Processing Record 31 of Set 8 | tanggulangin
# Processing Record 32 of Set 8 | teguldet
# Processing Record 33 of Set 8 | edd
# Processing Record 34 of Set 8 | beni
# Processing Record 35 of Set 8 | baherden
# Processing Record 36 of Set 8 | rocha
# Processing Record 37 of Set 8 | kavaratti
# Processing Record 38 of Set 8 | moussoro
# Processing Record 39 of Set 8 | byron bay
# Processing Record 40 of Set 8 | povenets
# Processing Record 41 of Set 8 | rakhya
# City not found. Skipping...
# Processing Record 42 of Set 8 | fort nelson
# Processing Record 43 of Set 8 | camocim
# Processing Record 44 of Set 8 | itamarandiba
# Processing Record 45 of Set 8 | smithers
# Processing Record 46 of Set 8 | auki
# Processing Record 47 of Set 8 | vao
# Processing Record 48 of Set 8 | samana
# Processing Record 49 of Set 8 | hvammstangi
# City not found. Skipping...
# Processing Record 50 of Set 8 | de-kastri
# Processing Record 1 of Set 9 | surt
# Processing Record 2 of Set 9 | cherskiy
# Processing Record 3 of Set 9 | agbor
# Processing Record 4 of Set 9 | igarape-miri
# City not found. Skipping...
# Processing Record 5 of Set 9 | kalimnos
# City not found. Skipping...
# Processing Record 6 of Set 9 | port-gentil
# Processing Record 7 of Set 9 | aswan
# Processing Record 8 of Set 9 | rabo de peixe
# Processing Record 9 of Set 9 | shache
# Processing Record 10 of Set 9 | sharjah
# Processing Record 11 of Set 9 | touros
# Processing Record 12 of Set 9 | bontang
# Processing Record 13 of Set 9 | khormuj
# City not found. Skipping...
# Processing Record 14 of Set 9 | ozernovskiy
# Processing Record 15 of Set 9 | namibe
# Processing Record 16 of Set 9 | camiri
# Processing Record 17 of Set 9 | spirit river
# Processing Record 18 of Set 9 | bilibino
# Processing Record 19 of Set 9 | ligayan
# Processing Record 20 of Set 9 | romitan
# Processing Record 21 of Set 9 | kruisfontein
# Processing Record 22 of Set 9 | alofi
# Processing Record 23 of Set 9 | tateyama
# Processing Record 24 of Set 9 | haines junction
# Processing Record 25 of Set 9 | verkhnyaya inta
# Processing Record 26 of Set 9 | ahipara
# Processing Record 27 of Set 9 | sao desiderio
# Processing Record 28 of Set 9 | kayes
# Processing Record 29 of Set 9 | agadir
# Processing Record 30 of Set 9 | carauari
# Processing Record 31 of Set 9 | comodoro rivadavia
# Processing Record 32 of Set 9 | padang
# Processing Record 33 of Set 9 | clearwater
# Processing Record 34 of Set 9 | gari
# Processing Record 35 of Set 9 | namatanai
# Processing Record 36 of Set 9 | westport
# Processing Record 37 of Set 9 | cheuskiny
# City not found. Skipping...
# Processing Record 38 of Set 9 | beisfjord
# Processing Record 39 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 9 | glencoe
# Processing Record 41 of Set 9 | quelimane
# Processing Record 42 of Set 9 | mecca
# Processing Record 43 of Set 9 | rasulabad
# Processing Record 44 of Set 9 | eirunepe
# Processing Record 45 of Set 9 | kupino
# Processing Record 46 of Set 9 | vigrestad
# Processing Record 47 of Set 9 | half moon bay
# Processing Record 48 of Set 9 | altoona
# Processing Record 49 of Set 9 | shilka
# Processing Record 50 of Set 9 | heze
# Processing Record 1 of Set 10 | nortelandia
# Processing Record 2 of Set 10 | nampula
# Processing Record 3 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 4 of Set 10 | athabasca
# Processing Record 5 of Set 10 | yulara
# Processing Record 6 of Set 10 | hammerfest
# Processing Record 7 of Set 10 | karaton
# Processing Record 8 of Set 10 | talalayivka
# Processing Record 9 of Set 10 | dongying
# Processing Record 10 of Set 10 | santa maria
# Processing Record 11 of Set 10 | saint anthony
# Processing Record 12 of Set 10 | flinders
# Processing Record 13 of Set 10 | kirakira
# Processing Record 14 of Set 10 | stephenville
# Processing Record 15 of Set 10 | fare
# Processing Record 16 of Set 10 | saint-augustin
# Processing Record 17 of Set 10 | erzin
# Processing Record 18 of Set 10 | taltal
# Processing Record 19 of Set 10 | tecoanapa
# Processing Record 20 of Set 10 | cherat
# Processing Record 21 of Set 10 | chuy
# Processing Record 22 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 23 of Set 10 | agirish
# Processing Record 24 of Set 10 | ambulu
# Processing Record 25 of Set 10 | tibiri
# Processing Record 26 of Set 10 | basco
# Processing Record 27 of Set 10 | yenagoa
# Processing Record 28 of Set 10 | nichinan
# Processing Record 29 of Set 10 | hohhot
# Processing Record 30 of Set 10 | norman wells
# Processing Record 31 of Set 10 | strezhevoy
# Processing Record 32 of Set 10 | cayhagan
# Processing Record 33 of Set 10 | trincomalee
# Processing Record 34 of Set 10 | warmbad
# Processing Record 35 of Set 10 | cooma
# Processing Record 36 of Set 10 | wahran
# City not found. Skipping...
# Processing Record 37 of Set 10 | snyder
# Processing Record 38 of Set 10 | lazaro cardenas
# Processing Record 39 of Set 10 | cabedelo
# Processing Record 40 of Set 10 | plerin
# Processing Record 41 of Set 10 | hamilton
# Processing Record 42 of Set 10 | tukan
# Processing Record 43 of Set 10 | ust-ilimsk
# Processing Record 44 of Set 10 | south venice
# Processing Record 45 of Set 10 | aguimes
# Processing Record 46 of Set 10 | luderitz
# Processing Record 47 of Set 10 | seoul
# Processing Record 48 of Set 10 | atambua
# Processing Record 49 of Set 10 | hanmer springs
# Processing Record 50 of Set 10 | ornes
# Processing Record 1 of Set 11 | grand gaube
# Processing Record 2 of Set 11 | bairiki
# Processing Record 3 of Set 11 | dwarka
# Processing Record 4 of Set 11 | ekhabi
# Processing Record 5 of Set 11 | buin
# Processing Record 6 of Set 11 | slonim
# Processing Record 7 of Set 11 | tiznit
# Processing Record 8 of Set 11 | pimenta bueno
# Processing Record 9 of Set 11 | ketchikan
# Processing Record 10 of Set 11 | pemberton
# Processing Record 11 of Set 11 | kulynychi
# Processing Record 12 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 13 of Set 11 | jibuti
# Processing Record 14 of Set 11 | santa rosa
# Processing Record 15 of Set 11 | rodrigues alves
# Processing Record 16 of Set 11 | kommunar
# Processing Record 17 of Set 11 | tailai
# Processing Record 18 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 19 of Set 11 | puga
# Processing Record 20 of Set 11 | armacao dos buzios
# City not found. Skipping...
# Processing Record 21 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 11 | bandarbeyla
# Processing Record 23 of Set 11 | trairi
# Processing Record 24 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 25 of Set 11 | felidhoo
# City not found. Skipping...
# Processing Record 26 of Set 11 | genhe
# Processing Record 27 of Set 11 | mae hong son
# Processing Record 28 of Set 11 | lorengau
# Processing Record 29 of Set 11 | itajobi
# Processing Record 30 of Set 11 | taraz
# Processing Record 31 of Set 11 | mushie
# Processing Record 32 of Set 11 | west wendover
# Processing Record 33 of Set 11 | jiroft
# City not found. Skipping...
# Processing Record 34 of Set 11 | guapore
# Processing Record 35 of Set 11 | pouembout
# Processing Record 36 of Set 11 | chengde
# Processing Record 37 of Set 11 | the valley
# Processing Record 38 of Set 11 | phuthaditjhaba
# Processing Record 39 of Set 11 | sorland
# Processing Record 40 of Set 11 | tarumovka
# Processing Record 41 of Set 11 | yudong
# Processing Record 42 of Set 11 | san quintin
# Processing Record 43 of Set 11 | price
# Processing Record 44 of Set 11 | begoro
# Processing Record 45 of Set 11 | helena
# Processing Record 46 of Set 11 | winnemucca
# Processing Record 47 of Set 11 | swellendam
# Processing Record 48 of Set 11 | belaya gora
# Processing Record 49 of Set 11 | alexandria
# Processing Record 50 of Set 11 | sidi qasim
# City not found. Skipping...
# Processing Record 1 of Set 12 | pacifica
# Processing Record 2 of Set 12 | poltavka
# Processing Record 3 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 4 of Set 12 | skibbereen
# Processing Record 5 of Set 12 | saint-louis
# Processing Record 6 of Set 12 | conceicao do araguaia
# Processing Record 7 of Set 12 | benghazi
# Processing Record 8 of Set 12 | berekum
# Processing Record 9 of Set 12 | constitucion
# Processing Record 10 of Set 12 | portland
# Processing Record 11 of Set 12 | shimoda
# Processing Record 12 of Set 12 | point pedro
# Processing Record 13 of Set 12 | tangzhai
# Processing Record 14 of Set 12 | grand-santi
# Processing Record 15 of Set 12 | male
# Processing Record 16 of Set 12 | opotiki
# Processing Record 17 of Set 12 | ust-kut
# Processing Record 18 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 19 of Set 12 | tual
# Processing Record 20 of Set 12 | rockport
# Processing Record 21 of Set 12 | barreirinha
# Processing Record 22 of Set 12 | penalva
# Processing Record 23 of Set 12 | puerto escondido
# Processing Record 24 of Set 12 | balkanabat
# Processing Record 25 of Set 12 | oistins
# Processing Record 26 of Set 12 | namtsy
# Processing Record 27 of Set 12 | aksu
# Processing Record 28 of Set 12 | corsicana
# Processing Record 29 of Set 12 | dali
# Processing Record 30 of Set 12 | guerrero negro
# Processing Record 31 of Set 12 | hargeysa
# Processing Record 32 of Set 12 | gondanglegi
# Processing Record 33 of Set 12 | hastings
# Processing Record 34 of Set 12 | yagodnoye
# Processing Record 35 of Set 12 | assiniboia
# Processing Record 36 of Set 12 | koson
# Processing Record 37 of Set 12 | sola
# Processing Record 38 of Set 12 | yining
# Processing Record 39 of Set 12 | saint-georges
# Processing Record 40 of Set 12 | qasigiannguit
# Processing Record 41 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 42 of Set 12 | santa marta
# Processing Record 43 of Set 12 | venice
# Processing Record 44 of Set 12 | honningsvag
# Processing Record 45 of Set 12 | we
# City not found. Skipping...
# Processing Record 46 of Set 12 | okhotsk
# Processing Record 47 of Set 12 | baykit
# Processing Record 48 of Set 12 | shingu
# Processing Record 49 of Set 12 | potam
# Processing Record 50 of Set 12 | cocobeach
# Processing Record 1 of Set 13 | viedma
# Processing Record 2 of Set 13 | illela
# Processing Record 3 of Set 13 | quesnel
# Processing Record 4 of Set 13 | awbari
# Processing Record 5 of Set 13 | manzil bu ruqaybah
# City not found. Skipping...
# Processing Record 6 of Set 13 | liwale
# Processing Record 7 of Set 13 | altay
# Processing Record 8 of Set 13 | college
# Processing Record 9 of Set 13 | katangli
# Processing Record 10 of Set 13 | flin flon
# Processing Record 11 of Set 13 | heihe
# Processing Record 12 of Set 13 | orocuina
# Processing Record 13 of Set 13 | itoman
# Processing Record 14 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 15 of Set 13 | champerico
# Processing Record 16 of Set 13 | ofaqim
# Processing Record 17 of Set 13 | moen
# Processing Record 18 of Set 13 | sansai
# City not found. Skipping...
# Processing Record 19 of Set 13 | lohja
# Processing Record 20 of Set 13 | tabory
# Processing Record 21 of Set 13 | vanavara
# Processing Record 22 of Set 13 | udachnyy
# Processing Record 23 of Set 13 | hami
# Processing Record 24 of Set 13 | buraydah
# Processing Record 25 of Set 13 | kununurra
# Processing Record 26 of Set 13 | chihuahua
# Processing Record 27 of Set 13 | carmelo
# Processing Record 28 of Set 13 | la rioja
# Processing Record 29 of Set 13 | grand baie
# Processing Record 30 of Set 13 | xining
# Processing Record 31 of Set 13 | wenling
# Processing Record 32 of Set 13 | valparaiso
# Processing Record 33 of Set 13 | atbasar
# Processing Record 34 of Set 13 | denpasar
# Processing Record 35 of Set 13 | novo cruzeiro
# Processing Record 36 of Set 13 | jinka
# Processing Record 37 of Set 13 | nakamura
# Processing Record 38 of Set 13 | malanje
# Processing Record 39 of Set 13 | charleston
# Processing Record 40 of Set 13 | maragogi
# Processing Record 41 of Set 13 | ixtapa
# Processing Record 42 of Set 13 | zhanakorgan
# Processing Record 43 of Set 13 | puerto carreno
# Processing Record 44 of Set 13 | broome
# Processing Record 45 of Set 13 | kytmanovo
# Processing Record 46 of Set 13 | turangi
# Processing Record 47 of Set 13 | moose factory
# Processing Record 48 of Set 13 | port hedland
# Processing Record 49 of Set 13 | sturgis
# Processing Record 50 of Set 13 | scottsbluff
# Processing Record 1 of Set 14 | oktyabrskoye
# Processing Record 2 of Set 14 | karamea
# City not found. Skipping...
# Processing Record 3 of Set 14 | tokur
# Processing Record 4 of Set 14 | burnie
# Processing Record 5 of Set 14 | nevelsk
# Processing Record 6 of Set 14 | chabua
# Processing Record 7 of Set 14 | belyy yar
# Processing Record 8 of Set 14 | winchester
# Processing Record 9 of Set 14 | savannakhet
# Processing Record 10 of Set 14 | londrina
# Processing Record 11 of Set 14 | nuevo progreso
# Processing Record 12 of Set 14 | arequipa
# Processing Record 13 of Set 14 | tazovskiy
# Processing Record 14 of Set 14 | pedernales
# Processing Record 15 of Set 14 | ulety
# Processing Record 16 of Set 14 | benguela
# Processing Record 17 of Set 14 | leshukonskoye
# Processing Record 18 of Set 14 | correntina
# Processing Record 19 of Set 14 | kapiri mposhi
# Processing Record 20 of Set 14 | domoni
# Processing Record 21 of Set 14 | sao miguel do araguaia
# Processing Record 22 of Set 14 | deputatskiy
# Processing Record 23 of Set 14 | mirabad
# Processing Record 24 of Set 14 | evensk
# Processing Record 25 of Set 14 | mabaruma
# Processing Record 26 of Set 14 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 27 of Set 14 | ratlam
# Processing Record 28 of Set 14 | khanpur
# Processing Record 29 of Set 14 | sobolevo
# Processing Record 30 of Set 14 | xadani
# City not found. Skipping...
# Processing Record 31 of Set 14 | kilgore
# Processing Record 32 of Set 14 | bennettsville
# Processing Record 33 of Set 14 | fergus falls
# Processing Record 34 of Set 14 | richards bay
# Processing Record 35 of Set 14 | mykhaylivka
# Processing Record 36 of Set 14 | azimur
# City not found. Skipping...
# Processing Record 37 of Set 14 | port keats
# Processing Record 38 of Set 14 | sosua
# Processing Record 39 of Set 14 | ostersund
# Processing Record 40 of Set 14 | horni plana
# Processing Record 41 of Set 14 | ucluelet
# Processing Record 42 of Set 14 | temaraia
# City not found. Skipping...
# Processing Record 43 of Set 14 | ormara
# Processing Record 44 of Set 14 | kestel
# Processing Record 45 of Set 14 | kaeo
# Processing Record 46 of Set 14 | ust-omchug
# Processing Record 47 of Set 14 | hofn
# Processing Record 48 of Set 14 | san felipe
# Processing Record 49 of Set 14 | seversk
# Processing Record 50 of Set 14 | stokmarknes
# Processing Record 1 of Set 15 | rolim de moura
# City not found. Skipping...
# Processing Record 2 of Set 15 | tourlaville
# Processing Record 3 of Set 15 | marsh harbour
# Processing Record 4 of Set 15 | bloemhof
# Processing Record 5 of Set 15 | emba
# Processing Record 6 of Set 15 | mayor pablo lagerenza
# Processing Record 7 of Set 15 | hakvik
# City not found. Skipping...
# Processing Record 8 of Set 15 | diego de almagro
# Processing Record 9 of Set 15 | la palma
# Processing Record 10 of Set 15 | fort-shevchenko
# Processing Record 11 of Set 15 | zychlin
# Processing Record 12 of Set 15 | merauke
# Processing Record 13 of Set 15 | goias
# Processing Record 14 of Set 15 | lasa
# Processing Record 15 of Set 15 | yangambi
# Processing Record 16 of Set 15 | solovetskiy
# City not found. Skipping...
# Processing Record 17 of Set 15 | korla
# Processing Record 18 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 19 of Set 15 | ampanihy
# Processing Record 20 of Set 15 | silale
# Processing Record 21 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 15 | teya
# Processing Record 23 of Set 15 | kenitra
# Processing Record 24 of Set 15 | skjervoy
# Processing Record 25 of Set 15 | lusambo
# Processing Record 26 of Set 15 | manggar
# Processing Record 27 of Set 15 | mayumba
# Processing Record 28 of Set 15 | nakhon phanom
# Processing Record 29 of Set 15 | anadyr
# Processing Record 30 of Set 15 | hokitika
# Processing Record 31 of Set 15 | suruc
# Processing Record 32 of Set 15 | doha
# Processing Record 33 of Set 15 | mana
# Processing Record 34 of Set 15 | abu kamal
# Processing Record 35 of Set 15 | yaounde
# Processing Record 36 of Set 15 | vega de alatorre
# Processing Record 37 of Set 15 | pangody
# Processing Record 38 of Set 15 | nabire
# Processing Record 39 of Set 15 | obidos
# Processing Record 40 of Set 15 | kyaikkami
# Processing Record 41 of Set 15 | kuching
# Processing Record 42 of Set 15 | talara
# Processing Record 43 of Set 15 | tezu
# Processing Record 44 of Set 15 | lethem
# Processing Record 45 of Set 15 | pundaguitan
# Processing Record 46 of Set 15 | bathsheba
# Processing Record 47 of Set 15 | le port
# Processing Record 48 of Set 15 | atikokan
# Processing Record 49 of Set 15 | mareeba
# Processing Record 50 of Set 15 | conway
# Processing Record 1 of Set 16 | carutapera
# Processing Record 2 of Set 16 | ialibu
# Processing Record 3 of Set 16 | tanabe
# Processing Record 4 of Set 16 | chapais
# Processing Record 5 of Set 16 | batagay-alyta
# Processing Record 6 of Set 16 | lubango
# Processing Record 7 of Set 16 | phek
# Processing Record 8 of Set 16 | abbeville
# Processing Record 9 of Set 16 | skagastrond
# City not found. Skipping...
# Processing Record 10 of Set 16 | tawkar
# City not found. Skipping...
# Processing Record 11 of Set 16 | lashio
# Processing Record 12 of Set 16 | iskateley
# Processing Record 13 of Set 16 | sandur
# Processing Record 14 of Set 16 | bilma
# Processing Record 15 of Set 16 | dillon
# Processing Record 16 of Set 16 | imbituba
# Processing Record 17 of Set 16 | kendari
# Processing Record 18 of Set 16 | shirhatti
# Processing Record 19 of Set 16 | mogadishu
# Processing Record 20 of Set 16 | singaraja
# Processing Record 21 of Set 16 | katherine
# Processing Record 22 of Set 16 | churapcha
# Processing Record 23 of Set 16 | coffs harbour
# Processing Record 24 of Set 16 | chiang khong
# Processing Record 25 of Set 16 | koutsouras
# Processing Record 26 of Set 16 | kargasok
# Processing Record 27 of Set 16 | wang noi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 712

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Mangalia  43.8000   28.5833     50.68        73          51
# 1             Hilo  19.7297 -155.0900     81.25        83           0
# 2           Albany  42.6001  -73.9662     34.57        67          62
# 3         Souillac -20.5167   57.5167     61.18        88          20
# 4   Saint-Philippe -21.3585   55.7679     69.39        72          23
# 5       Nanortalik  60.1432  -45.2371     22.82        72         100
# 6  Arraial Do Cabo -22.9661  -42.0278     71.22        73           0
# 7          Mataura -46.1927  168.8643     58.48        59          92
# 8         Khatanga  71.9667  102.5000    -21.87        89          99
# 9           Mattru   7.6244  -11.8332     73.22        92          62
#
#    Wind Speed Country Current Description
# 0        3.53      RO       broken clouds
# 1       11.50      US           clear sky
# 2        1.01      US       broken clouds
# 3        6.91      MU          few clouds
# 4        3.78      RE          few clouds
# 5        3.91      GL     overcast clouds
# 6        6.24      BR           clear sky
# 7        1.43      NZ     overcast clouds
# 8        9.15      RU     overcast clouds
# 9        0.29      SL       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
city_data_new = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description'] 

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[city_data_new]

# Display sample data
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Mangalia      RO  43.8000   28.5833     50.68        73          51
# 1             Hilo      US  19.7297 -155.0900     81.25        83           0
# 2           Albany      US  42.6001  -73.9662     34.57        67          62
# 3         Souillac      MU -20.5167   57.5167     61.18        88          20
# 4   Saint-Philippe      RE -21.3585   55.7679     69.39        72          23
# 5       Nanortalik      GL  60.1432  -45.2371     22.82        72         100
# 6  Arraial Do Cabo      BR -22.9661  -42.0278     71.22        73           0
# 7          Mataura      NZ -46.1927  168.8643     58.48        59          92
# 8         Khatanga      RU  71.9667  102.5000    -21.87        89          99
# 9           Mattru      SL   7.6244  -11.8332     73.22        92          62
#
#    Wind Speed Current Description
# 0        3.53       broken clouds
# 1       11.50           clear sky
# 2        1.01       broken clouds
# 3        6.91          few clouds
# 4        3.78          few clouds
# 5        3.91     overcast clouds
# 6        6.24           clear sky
# 7        1.43     overcast clouds
# 8        9.15     overcast clouds
# 9        0.29       broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
