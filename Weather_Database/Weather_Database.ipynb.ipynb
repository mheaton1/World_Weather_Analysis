# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 707

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = 'https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=' + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        lat=city_weather["coord"]["lat"]
        lng=city_weather["coord"]["lon"]
        max_temp=city_weather["main"]["temp_max"]
        humidity=city_weather["main"]["humidity"]
        cloudiness=city_weather["clouds"]["all"]
        wind=city_weather["wind"]["speed"]
        country=city_weather["sys"]["country"]
        description=city_weather["weather"][0]["description"]      
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": lat,
                          "Lng": lng,
                          "Max Temp": max_temp,
                          "Humidity": humidity,
                          "Cloudiness": cloudiness,
                          "Wind Speed": wind,
                          "Country": country,
                          "Current Description": description
                         })
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | roebourne
# Processing Record 3 of Set 1 | jiddah
# City not found. Skipping...
# Processing Record 4 of Set 1 | yellowknife
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 1 | pombal
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | grindavik
# Processing Record 10 of Set 1 | valencia
# Processing Record 11 of Set 1 | copiapo
# Processing Record 12 of Set 1 | mecca
# Processing Record 13 of Set 1 | wewak
# Processing Record 14 of Set 1 | college
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | hobart
# Processing Record 19 of Set 1 | provideniya
# Processing Record 20 of Set 1 | barrow
# Processing Record 21 of Set 1 | atuona
# Processing Record 22 of Set 1 | port hueneme
# Processing Record 23 of Set 1 | puerto ayora
# Processing Record 24 of Set 1 | cidreira
# Processing Record 25 of Set 1 | ribeira grande
# Processing Record 26 of Set 1 | geraldton
# Processing Record 27 of Set 1 | phan thiet
# Processing Record 28 of Set 1 | port blair
# Processing Record 29 of Set 1 | saint-augustin
# Processing Record 30 of Set 1 | bardiyah
# Processing Record 31 of Set 1 | aklavik
# Processing Record 32 of Set 1 | albany
# Processing Record 33 of Set 1 | soe
# Processing Record 34 of Set 1 | wasilla
# Processing Record 35 of Set 1 | kirakira
# Processing Record 36 of Set 1 | ouallam
# Processing Record 37 of Set 1 | artyk
# City not found. Skipping...
# Processing Record 38 of Set 1 | pandan
# Processing Record 39 of Set 1 | mirnyy
# Processing Record 40 of Set 1 | isangel
# Processing Record 41 of Set 1 | mahebourg
# Processing Record 42 of Set 1 | port hardy
# Processing Record 43 of Set 1 | moyamba
# Processing Record 44 of Set 1 | castro
# Processing Record 45 of Set 1 | smithers
# Processing Record 46 of Set 1 | sembe
# Processing Record 47 of Set 1 | gonzalez
# Processing Record 48 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 49 of Set 1 | atar
# Processing Record 50 of Set 1 | dingle
# Processing Record 1 of Set 2 | kavaratti
# Processing Record 2 of Set 2 | torbay
# Processing Record 3 of Set 2 | lebu
# Processing Record 4 of Set 2 | carnarvon
# Processing Record 5 of Set 2 | tuktoyaktuk
# Processing Record 6 of Set 2 | hermanus
# Processing Record 7 of Set 2 | klaksvik
# Processing Record 8 of Set 2 | port-cartier
# Processing Record 9 of Set 2 | port alfred
# Processing Record 10 of Set 2 | axim
# Processing Record 11 of Set 2 | pevek
# Processing Record 12 of Set 2 | lethem
# Processing Record 13 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 2 | khatanga
# Processing Record 15 of Set 2 | chuy
# Processing Record 16 of Set 2 | meulaboh
# Processing Record 17 of Set 2 | manzhouli
# Processing Record 18 of Set 2 | sola
# Processing Record 19 of Set 2 | kasongo-lunda
# Processing Record 20 of Set 2 | santa marta
# Processing Record 21 of Set 2 | new norfolk
# Processing Record 22 of Set 2 | qaanaaq
# Processing Record 23 of Set 2 | gimli
# Processing Record 24 of Set 2 | kodiak
# Processing Record 25 of Set 2 | talnakh
# Processing Record 26 of Set 2 | bluff
# Processing Record 27 of Set 2 | lampa
# Processing Record 28 of Set 2 | saint-philippe
# Processing Record 29 of Set 2 | riyadh
# Processing Record 30 of Set 2 | saldanha
# Processing Record 31 of Set 2 | elat
# Processing Record 32 of Set 2 | begowala
# Processing Record 33 of Set 2 | bambous virieux
# Processing Record 34 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 2 | butaritari
# Processing Record 36 of Set 2 | swan hill
# Processing Record 37 of Set 2 | high level
# Processing Record 38 of Set 2 | paamiut
# Processing Record 39 of Set 2 | kalabo
# Processing Record 40 of Set 2 | gat
# Processing Record 41 of Set 2 | port macquarie
# Processing Record 42 of Set 2 | upernavik
# Processing Record 43 of Set 2 | port-gentil
# Processing Record 44 of Set 2 | pitelino
# Processing Record 45 of Set 2 | hithadhoo
# Processing Record 46 of Set 2 | hasaki
# Processing Record 47 of Set 2 | nanortalik
# Processing Record 48 of Set 2 | kruisfontein
# Processing Record 49 of Set 2 | manono
# Processing Record 50 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 3 | mitsamiouli
# Processing Record 2 of Set 3 | mar del plata
# Processing Record 3 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 3 | gayny
# Processing Record 5 of Set 3 | vestmannaeyjar
# Processing Record 6 of Set 3 | ancud
# Processing Record 7 of Set 3 | athabasca
# Processing Record 8 of Set 3 | saint-pierre
# Processing Record 9 of Set 3 | guerrero negro
# Processing Record 10 of Set 3 | nanning
# Processing Record 11 of Set 3 | faya
# Processing Record 12 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 13 of Set 3 | kobryn
# Processing Record 14 of Set 3 | calama
# Processing Record 15 of Set 3 | dunedin
# Processing Record 16 of Set 3 | portland
# Processing Record 17 of Set 3 | shebunino
# Processing Record 18 of Set 3 | pisco
# Processing Record 19 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 20 of Set 3 | buala
# Processing Record 21 of Set 3 | indramayu
# Processing Record 22 of Set 3 | sao geraldo do araguaia
# Processing Record 23 of Set 3 | kurilsk
# Processing Record 24 of Set 3 | mataura
# Processing Record 25 of Set 3 | tiksi
# Processing Record 26 of Set 3 | avarua
# Processing Record 27 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 3 | salaga
# Processing Record 29 of Set 3 | lagoa
# Processing Record 30 of Set 3 | nome
# Processing Record 31 of Set 3 | silale
# Processing Record 32 of Set 3 | katsuura
# Processing Record 33 of Set 3 | jamestown
# Processing Record 34 of Set 3 | tombouctou
# Processing Record 35 of Set 3 | ponta do sol
# Processing Record 36 of Set 3 | chardara
# Processing Record 37 of Set 3 | kapaa
# Processing Record 38 of Set 3 | codrington
# Processing Record 39 of Set 3 | sambava
# Processing Record 40 of Set 3 | bolshaya sosnova
# Processing Record 41 of Set 3 | ust-nera
# Processing Record 42 of Set 3 | hofn
# Processing Record 43 of Set 3 | wahran
# City not found. Skipping...
# Processing Record 44 of Set 3 | tiznit
# Processing Record 45 of Set 3 | madang
# Processing Record 46 of Set 3 | tahe
# Processing Record 47 of Set 3 | esperance
# Processing Record 48 of Set 3 | general roca
# Processing Record 49 of Set 3 | kununurra
# Processing Record 50 of Set 3 | macaboboni
# City not found. Skipping...
# Processing Record 1 of Set 4 | port elizabeth
# Processing Record 2 of Set 4 | dikson
# Processing Record 3 of Set 4 | shima
# Processing Record 4 of Set 4 | ossora
# Processing Record 5 of Set 4 | fortuna
# Processing Record 6 of Set 4 | sudak
# Processing Record 7 of Set 4 | anaconda
# Processing Record 8 of Set 4 | jutai
# Processing Record 9 of Set 4 | gamba
# Processing Record 10 of Set 4 | port augusta
# Processing Record 11 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 12 of Set 4 | hailey
# Processing Record 13 of Set 4 | georgetown
# Processing Record 14 of Set 4 | erzurum
# Processing Record 15 of Set 4 | imbituba
# Processing Record 16 of Set 4 | karratha
# Processing Record 17 of Set 4 | kilindoni
# Processing Record 18 of Set 4 | nefteyugansk
# Processing Record 19 of Set 4 | namatanai
# Processing Record 20 of Set 4 | garowe
# Processing Record 21 of Set 4 | hamilton
# Processing Record 22 of Set 4 | tura
# Processing Record 23 of Set 4 | nyurba
# Processing Record 24 of Set 4 | kota kinabalu
# Processing Record 25 of Set 4 | norman wells
# Processing Record 26 of Set 4 | sitka
# Processing Record 27 of Set 4 | san patricio
# Processing Record 28 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 4 | east london
# Processing Record 30 of Set 4 | lhokseumawe
# Processing Record 31 of Set 4 | guanare
# Processing Record 32 of Set 4 | chokurdakh
# Processing Record 33 of Set 4 | mullaitivu
# City not found. Skipping...
# Processing Record 34 of Set 4 | saskylakh
# Processing Record 35 of Set 4 | vila do maio
# Processing Record 36 of Set 4 | cabo san lucas
# Processing Record 37 of Set 4 | sao jose da coroa grande
# Processing Record 38 of Set 4 | emerald
# Processing Record 39 of Set 4 | lorengau
# Processing Record 40 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 4 | yulara
# Processing Record 42 of Set 4 | moranbah
# Processing Record 43 of Set 4 | lahaina
# Processing Record 44 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 4 | bandundu
# Processing Record 46 of Set 4 | hilo
# Processing Record 47 of Set 4 | vuktyl
# Processing Record 48 of Set 4 | namibe
# Processing Record 49 of Set 4 | lompoc
# Processing Record 50 of Set 4 | auki
# Processing Record 1 of Set 5 | belaya gora
# Processing Record 2 of Set 5 | jalu
# Processing Record 3 of Set 5 | cape town
# Processing Record 4 of Set 5 | poddorye
# Processing Record 5 of Set 5 | praya
# Processing Record 6 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 5 | abay
# Processing Record 8 of Set 5 | severo-kurilsk
# Processing Record 9 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 10 of Set 5 | olovyannaya
# Processing Record 11 of Set 5 | bredasdorp
# Processing Record 12 of Set 5 | lang son
# Processing Record 13 of Set 5 | ngunguru
# Processing Record 14 of Set 5 | zuwarah
# Processing Record 15 of Set 5 | ambon
# Processing Record 16 of Set 5 | raudeberg
# Processing Record 17 of Set 5 | manjacaze
# Processing Record 18 of Set 5 | thompson
# Processing Record 19 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 5 | dzhebariki-khaya
# Processing Record 21 of Set 5 | owando
# Processing Record 22 of Set 5 | vao
# Processing Record 23 of Set 5 | nikolskoye
# Processing Record 24 of Set 5 | valledupar
# Processing Record 25 of Set 5 | hirara
# Processing Record 26 of Set 5 | husavik
# Processing Record 27 of Set 5 | iqaluit
# Processing Record 28 of Set 5 | goderich
# Processing Record 29 of Set 5 | urulga
# City not found. Skipping...
# Processing Record 30 of Set 5 | taltal
# Processing Record 31 of Set 5 | arona
# Processing Record 32 of Set 5 | kyabe
# Processing Record 33 of Set 5 | huarmey
# Processing Record 34 of Set 5 | khani
# Processing Record 35 of Set 5 | soure
# Processing Record 36 of Set 5 | duartina
# Processing Record 37 of Set 5 | padang
# Processing Record 38 of Set 5 | souillac
# Processing Record 39 of Set 5 | victoria
# Processing Record 40 of Set 5 | londrina
# Processing Record 41 of Set 5 | touros
# Processing Record 42 of Set 5 | bethel
# Processing Record 43 of Set 5 | saint anthony
# Processing Record 44 of Set 5 | obrnice
# Processing Record 45 of Set 5 | vostok
# Processing Record 46 of Set 5 | shuangcheng
# Processing Record 47 of Set 5 | eureka
# Processing Record 48 of Set 5 | bundibugyo
# Processing Record 49 of Set 5 | camana
# Processing Record 50 of Set 5 | lavrentiya
# Processing Record 1 of Set 6 | sile
# Processing Record 2 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 6 | leningradskiy
# Processing Record 4 of Set 6 | arraial do cabo
# Processing Record 5 of Set 6 | bogense
# Processing Record 6 of Set 6 | baruun-urt
# Processing Record 7 of Set 6 | plettenberg bay
# Processing Record 8 of Set 6 | oktyabrskoye
# Processing Record 9 of Set 6 | vila velha
# Processing Record 10 of Set 6 | ivanivka
# Processing Record 11 of Set 6 | aswan
# Processing Record 12 of Set 6 | miles city
# Processing Record 13 of Set 6 | lubao
# Processing Record 14 of Set 6 | arazede
# Processing Record 15 of Set 6 | bereda
# Processing Record 16 of Set 6 | itarema
# Processing Record 17 of Set 6 | grand-santi
# Processing Record 18 of Set 6 | northfield
# Processing Record 19 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 6 | nishihara
# Processing Record 21 of Set 6 | gizo
# Processing Record 22 of Set 6 | berdigestyakh
# Processing Record 23 of Set 6 | pangody
# Processing Record 24 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 25 of Set 6 | shitanjing
# Processing Record 26 of Set 6 | karauzyak
# City not found. Skipping...
# Processing Record 27 of Set 6 | svobodnyy
# Processing Record 28 of Set 6 | miguel alves
# Processing Record 29 of Set 6 | nouadhibou
# Processing Record 30 of Set 6 | comodoro rivadavia
# Processing Record 31 of Set 6 | vardo
# Processing Record 32 of Set 6 | huautla
# Processing Record 33 of Set 6 | taoudenni
# Processing Record 34 of Set 6 | port shepstone
# Processing Record 35 of Set 6 | sobolevo
# Processing Record 36 of Set 6 | barra do garcas
# Processing Record 37 of Set 6 | omboue
# Processing Record 38 of Set 6 | mlonggo
# Processing Record 39 of Set 6 | khartoum
# Processing Record 40 of Set 6 | magadan
# Processing Record 41 of Set 6 | beringovskiy
# Processing Record 42 of Set 6 | salalah
# Processing Record 43 of Set 6 | ojinaga
# Processing Record 44 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 45 of Set 6 | doha
# Processing Record 46 of Set 6 | bubaque
# Processing Record 47 of Set 6 | matagami
# Processing Record 48 of Set 6 | goba
# Processing Record 49 of Set 6 | panarukan
# Processing Record 50 of Set 6 | port lincoln
# Processing Record 1 of Set 7 | udachnyy
# Processing Record 2 of Set 7 | ilulissat
# Processing Record 3 of Set 7 | colesberg
# Processing Record 4 of Set 7 | aksarka
# Processing Record 5 of Set 7 | nkhata bay
# Processing Record 6 of Set 7 | luganville
# Processing Record 7 of Set 7 | inyonga
# Processing Record 8 of Set 7 | vila franca do campo
# Processing Record 9 of Set 7 | geresk
# City not found. Skipping...
# Processing Record 10 of Set 7 | broken hill
# Processing Record 11 of Set 7 | lincoln
# Processing Record 12 of Set 7 | mandera
# Processing Record 13 of Set 7 | eganville
# Processing Record 14 of Set 7 | bambanglipuro
# Processing Record 15 of Set 7 | san rafael
# Processing Record 16 of Set 7 | kaitangata
# Processing Record 17 of Set 7 | tasiilaq
# Processing Record 18 of Set 7 | lashio
# Processing Record 19 of Set 7 | saint-leu
# Processing Record 20 of Set 7 | cedar city
# Processing Record 21 of Set 7 | egvekinot
# Processing Record 22 of Set 7 | ternate
# Processing Record 23 of Set 7 | sparks
# Processing Record 24 of Set 7 | vidim
# Processing Record 25 of Set 7 | nioro
# Processing Record 26 of Set 7 | sao joao da barra
# Processing Record 27 of Set 7 | noumea
# Processing Record 28 of Set 7 | maxixe
# Processing Record 29 of Set 7 | luderitz
# Processing Record 30 of Set 7 | airai
# Processing Record 31 of Set 7 | araouane
# Processing Record 32 of Set 7 | rudnya
# Processing Record 33 of Set 7 | bathsheba
# Processing Record 34 of Set 7 | kaya
# Processing Record 35 of Set 7 | goma
# Processing Record 36 of Set 7 | matara
# Processing Record 37 of Set 7 | wuwei
# Processing Record 38 of Set 7 | yar-sale
# Processing Record 39 of Set 7 | upala
# Processing Record 40 of Set 7 | peniche
# Processing Record 41 of Set 7 | hammerfest
# Processing Record 42 of Set 7 | simpang
# Processing Record 43 of Set 7 | komsomolskiy
# Processing Record 44 of Set 7 | maldonado
# Processing Record 45 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 7 | srednekolymsk
# Processing Record 47 of Set 7 | batagay-alyta
# Processing Record 48 of Set 7 | qurayyat
# Processing Record 49 of Set 7 | talawdi
# City not found. Skipping...
# Processing Record 50 of Set 7 | prince rupert
# Processing Record 1 of Set 8 | cherskiy
# Processing Record 2 of Set 8 | walvis bay
# Processing Record 3 of Set 8 | progreso
# Processing Record 4 of Set 8 | puerto madryn
# Processing Record 5 of Set 8 | glenwood springs
# Processing Record 6 of Set 8 | fort nelson
# Processing Record 7 of Set 8 | beckley
# Processing Record 8 of Set 8 | poronaysk
# Processing Record 9 of Set 8 | sumbe
# Processing Record 10 of Set 8 | porto novo
# Processing Record 11 of Set 8 | nata
# Processing Record 12 of Set 8 | houma
# Processing Record 13 of Set 8 | longyearbyen
# Processing Record 14 of Set 8 | richards bay
# Processing Record 15 of Set 8 | kalga
# Processing Record 16 of Set 8 | marquette
# Processing Record 17 of Set 8 | saint george
# Processing Record 18 of Set 8 | sao filipe
# Processing Record 19 of Set 8 | diamantino
# Processing Record 20 of Set 8 | san cristobal
# Processing Record 21 of Set 8 | kieta
# Processing Record 22 of Set 8 | khandbari
# Processing Record 23 of Set 8 | half moon bay
# Processing Record 24 of Set 8 | bangassou
# Processing Record 25 of Set 8 | puerto escondido
# Processing Record 26 of Set 8 | nhulunbuy
# Processing Record 27 of Set 8 | buraydah
# Processing Record 28 of Set 8 | smirnykh
# Processing Record 29 of Set 8 | tagusao
# Processing Record 30 of Set 8 | sinnamary
# Processing Record 31 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 32 of Set 8 | pingliang
# Processing Record 33 of Set 8 | izumo
# Processing Record 34 of Set 8 | lasa
# Processing Record 35 of Set 8 | tokur
# Processing Record 36 of Set 8 | linjiang
# Processing Record 37 of Set 8 | muramvya
# Processing Record 38 of Set 8 | okha
# Processing Record 39 of Set 8 | rio cuarto
# Processing Record 40 of Set 8 | yuli
# Processing Record 41 of Set 8 | pangnirtung
# Processing Record 42 of Set 8 | luoyang
# Processing Record 43 of Set 8 | falealupo
# City not found. Skipping...
# Processing Record 44 of Set 8 | coahuayana
# Processing Record 45 of Set 8 | yokadouma
# Processing Record 46 of Set 8 | callaway
# Processing Record 47 of Set 8 | mehamn
# Processing Record 48 of Set 8 | sur
# Processing Record 49 of Set 8 | cooma
# Processing Record 50 of Set 8 | concarneau
# Processing Record 1 of Set 9 | high rock
# Processing Record 2 of Set 9 | jizan
# Processing Record 3 of Set 9 | saint-francois
# Processing Record 4 of Set 9 | anamur
# Processing Record 5 of Set 9 | bilibino
# Processing Record 6 of Set 9 | maputo
# Processing Record 7 of Set 9 | champerico
# Processing Record 8 of Set 9 | zhigansk
# Processing Record 9 of Set 9 | calvinia
# Processing Record 10 of Set 9 | sisimiut
# Processing Record 11 of Set 9 | takoradi
# Processing Record 12 of Set 9 | green river
# Processing Record 13 of Set 9 | haines junction
# Processing Record 14 of Set 9 | nileshwar
# Processing Record 15 of Set 9 | vysokogornyy
# Processing Record 16 of Set 9 | botwood
# Processing Record 17 of Set 9 | grand gaube
# Processing Record 18 of Set 9 | uwayl
# City not found. Skipping...
# Processing Record 19 of Set 9 | boda
# Processing Record 20 of Set 9 | douglasville
# Processing Record 21 of Set 9 | narsaq
# Processing Record 22 of Set 9 | whittlesea
# Processing Record 23 of Set 9 | thayetmyo
# Processing Record 24 of Set 9 | honiara
# Processing Record 25 of Set 9 | biak
# Processing Record 26 of Set 9 | anadyr
# Processing Record 27 of Set 9 | olcea
# Processing Record 28 of Set 9 | tigil
# Processing Record 29 of Set 9 | cayenne
# Processing Record 30 of Set 9 | lakes entrance
# Processing Record 31 of Set 9 | dudinka
# Processing Record 32 of Set 9 | pascagoula
# Processing Record 33 of Set 9 | saint-georges
# Processing Record 34 of Set 9 | pochutla
# Processing Record 35 of Set 9 | ostrovnoy
# Processing Record 36 of Set 9 | kushmurun
# Processing Record 37 of Set 9 | kangaatsiaq
# Processing Record 38 of Set 9 | outram
# Processing Record 39 of Set 9 | humboldt
# Processing Record 40 of Set 9 | russell
# Processing Record 41 of Set 9 | havelock
# Processing Record 42 of Set 9 | beruwala
# Processing Record 43 of Set 9 | chichawatni
# Processing Record 44 of Set 9 | lewistown
# Processing Record 45 of Set 9 | tuatapere
# Processing Record 46 of Set 9 | mount gambier
# Processing Record 47 of Set 9 | ust-charyshskaya pristan
# Processing Record 48 of Set 9 | naze
# Processing Record 49 of Set 9 | mokrousovo
# Processing Record 50 of Set 9 | neiafu
# Processing Record 1 of Set 10 | khabary
# Processing Record 2 of Set 10 | matay
# Processing Record 3 of Set 10 | saint-joseph
# Processing Record 4 of Set 10 | juneau
# Processing Record 5 of Set 10 | oktyabrskiy
# Processing Record 6 of Set 10 | hualmay
# Processing Record 7 of Set 10 | kavieng
# Processing Record 8 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 9 of Set 10 | play cu
# City not found. Skipping...
# Processing Record 10 of Set 10 | boyolangu
# Processing Record 11 of Set 10 | genhe
# Processing Record 12 of Set 10 | hobyo
# Processing Record 13 of Set 10 | jinxiang
# Processing Record 14 of Set 10 | kefalovrison
# City not found. Skipping...
# Processing Record 15 of Set 10 | brae
# Processing Record 16 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 10 | luanda
# Processing Record 18 of Set 10 | bonthe
# Processing Record 19 of Set 10 | faanui
# Processing Record 20 of Set 10 | australind
# Processing Record 21 of Set 10 | negele
# City not found. Skipping...
# Processing Record 22 of Set 10 | chiredzi
# Processing Record 23 of Set 10 | khandyga
# Processing Record 24 of Set 10 | clyde river
# Processing Record 25 of Set 10 | ribeira brava
# Processing Record 26 of Set 10 | korla
# Processing Record 27 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 28 of Set 10 | bahia honda
# Processing Record 29 of Set 10 | taunggyi
# Processing Record 30 of Set 10 | tutoia
# Processing Record 31 of Set 10 | pak phanang
# Processing Record 32 of Set 10 | mabaruma
# Processing Record 33 of Set 10 | fairview
# Processing Record 34 of Set 10 | churapcha
# Processing Record 35 of Set 10 | thomaston
# Processing Record 36 of Set 10 | astana
# Processing Record 37 of Set 10 | strezhevoy
# Processing Record 38 of Set 10 | lluta
# Processing Record 39 of Set 10 | marsh harbour
# Processing Record 40 of Set 10 | kahului
# Processing Record 41 of Set 10 | bogale
# Processing Record 42 of Set 10 | lata
# Processing Record 43 of Set 10 | jackson
# Processing Record 44 of Set 10 | rio gallegos
# Processing Record 45 of Set 10 | point fortin
# Processing Record 46 of Set 10 | xingyi
# Processing Record 47 of Set 10 | argelia
# Processing Record 48 of Set 10 | gilgit
# Processing Record 49 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 50 of Set 10 | gulshat
# City not found. Skipping...
# Processing Record 1 of Set 11 | buqayq
# City not found. Skipping...
# Processing Record 2 of Set 11 | casablanca
# Processing Record 3 of Set 11 | mackay
# Processing Record 4 of Set 11 | ust-maya
# Processing Record 5 of Set 11 | santa cruz del sur
# Processing Record 6 of Set 11 | tarija
# Processing Record 7 of Set 11 | ishigaki
# Processing Record 8 of Set 11 | jinchang
# Processing Record 9 of Set 11 | san jose
# Processing Record 10 of Set 11 | clarence town
# Processing Record 11 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 12 of Set 11 | bay city
# Processing Record 13 of Set 11 | bridgeton
# Processing Record 14 of Set 11 | oxford
# Processing Record 15 of Set 11 | koyilandi
# City not found. Skipping...
# Processing Record 16 of Set 11 | dharangaon
# Processing Record 17 of Set 11 | san quintin
# Processing Record 18 of Set 11 | mayo
# Processing Record 19 of Set 11 | maumere
# Processing Record 20 of Set 11 | ahipara
# Processing Record 21 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 22 of Set 11 | yumbel
# Processing Record 23 of Set 11 | bengkulu
# Processing Record 24 of Set 11 | wenling
# Processing Record 25 of Set 11 | tinskoy
# Processing Record 26 of Set 11 | plainview
# Processing Record 27 of Set 11 | andilamena
# Processing Record 28 of Set 11 | ulaangom
# Processing Record 29 of Set 11 | dzaoudzi
# Processing Record 30 of Set 11 | asyut
# Processing Record 31 of Set 11 | verkhnevilyuysk
# Processing Record 32 of Set 11 | manokwari
# Processing Record 33 of Set 11 | campoverde
# Processing Record 34 of Set 11 | denpasar
# Processing Record 35 of Set 11 | coihaique
# Processing Record 36 of Set 11 | sao raimundo das mangabeiras
# Processing Record 37 of Set 11 | abbeville
# Processing Record 38 of Set 11 | vitina
# Processing Record 39 of Set 11 | bandarbeyla
# Processing Record 40 of Set 11 | balkanabat
# Processing Record 41 of Set 11 | caravelas
# Processing Record 42 of Set 11 | biloela
# Processing Record 43 of Set 11 | kumluca
# Processing Record 44 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 45 of Set 11 | mao
# Processing Record 46 of Set 11 | billingham
# Processing Record 47 of Set 11 | shimoda
# Processing Record 48 of Set 11 | boa vista
# Processing Record 49 of Set 11 | tual
# Processing Record 50 of Set 11 | mpika
# Processing Record 1 of Set 12 | ucluelet
# Processing Record 2 of Set 12 | yatou
# Processing Record 3 of Set 12 | paraiso
# Processing Record 4 of Set 12 | karpogory
# Processing Record 5 of Set 12 | mezen
# Processing Record 6 of Set 12 | havre-saint-pierre
# Processing Record 7 of Set 12 | fayaoue
# Processing Record 8 of Set 12 | constitucion
# Processing Record 9 of Set 12 | jinchengjiang
# City not found. Skipping...
# Processing Record 10 of Set 12 | mitzic
# Processing Record 11 of Set 12 | agfalva
# Processing Record 12 of Set 12 | sicamous
# Processing Record 13 of Set 12 | shorapani
# Processing Record 14 of Set 12 | fuling
# Processing Record 15 of Set 12 | henties bay
# Processing Record 16 of Set 12 | narrabri
# Processing Record 17 of Set 12 | brainerd
# Processing Record 18 of Set 12 | duma
# Processing Record 19 of Set 12 | rumuruti
# Processing Record 20 of Set 12 | katherine
# Processing Record 21 of Set 12 | morwell
# Processing Record 22 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 23 of Set 12 | nazas
# Processing Record 24 of Set 12 | muhos
# Processing Record 25 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 26 of Set 12 | yining
# Processing Record 27 of Set 12 | cape elizabeth
# City not found. Skipping...
# Processing Record 28 of Set 12 | agucadoura
# Processing Record 29 of Set 12 | feijo
# Processing Record 30 of Set 12 | camacha
# Processing Record 31 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 32 of Set 12 | verkhoyansk
# Processing Record 33 of Set 12 | bucerias
# Processing Record 34 of Set 12 | sept-iles
# Processing Record 35 of Set 12 | salinopolis
# Processing Record 36 of Set 12 | guiglo
# Processing Record 37 of Set 12 | urucara
# Processing Record 38 of Set 12 | tavda
# Processing Record 39 of Set 12 | changping
# Processing Record 40 of Set 12 | senanga
# Processing Record 41 of Set 12 | bitung
# Processing Record 42 of Set 12 | aleksandrov gay
# Processing Record 43 of Set 12 | turayf
# Processing Record 44 of Set 12 | oxapampa
# Processing Record 45 of Set 12 | awjilah
# Processing Record 46 of Set 12 | hildburghausen
# Processing Record 47 of Set 12 | katangli
# Processing Record 48 of Set 12 | kalmunai
# Processing Record 49 of Set 12 | handan
# Processing Record 50 of Set 12 | makakilo city
# Processing Record 1 of Set 13 | oriximina
# Processing Record 2 of Set 13 | uglegorsk
# Processing Record 3 of Set 13 | marrakesh
# Processing Record 4 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 5 of Set 13 | vanino
# Processing Record 6 of Set 13 | fez
# Processing Record 7 of Set 13 | ende
# Processing Record 8 of Set 13 | coquimbo
# Processing Record 9 of Set 13 | dharchula
# Processing Record 10 of Set 13 | potgietersrus
# City not found. Skipping...
# Processing Record 11 of Set 13 | waipawa
# Processing Record 12 of Set 13 | carballo
# Processing Record 13 of Set 13 | banapur
# Processing Record 14 of Set 13 | magugu
# Processing Record 15 of Set 13 | baherden
# Processing Record 16 of Set 13 | phayao
# Processing Record 17 of Set 13 | misratah
# Processing Record 18 of Set 13 | coos bay
# Processing Record 19 of Set 13 | calatrava
# Processing Record 20 of Set 13 | halifax
# Processing Record 21 of Set 13 | kilmez
# City not found. Skipping...
# Processing Record 22 of Set 13 | olafsvik
# Processing Record 23 of Set 13 | mikhaylovka
# Processing Record 24 of Set 13 | goundam
# Processing Record 25 of Set 13 | tricase
# Processing Record 26 of Set 13 | kasulu
# Processing Record 27 of Set 13 | emba
# Processing Record 28 of Set 13 | guanica
# Processing Record 29 of Set 13 | adre
# Processing Record 30 of Set 13 | pasni
# Processing Record 31 of Set 13 | avera
# Processing Record 32 of Set 13 | qaqortoq
# Processing Record 33 of Set 13 | licata
# Processing Record 34 of Set 13 | jumla
# Processing Record 35 of Set 13 | belyy yar
# Processing Record 36 of Set 13 | almaty
# Processing Record 37 of Set 13 | nantucket
# Processing Record 38 of Set 13 | hyeres
# Processing Record 39 of Set 13 | tevriz
# Processing Record 40 of Set 13 | gangotri
# City not found. Skipping...
# Processing Record 41 of Set 13 | lipnita
# Processing Record 42 of Set 13 | maine-soroa
# Processing Record 43 of Set 13 | bac lieu
# Processing Record 44 of Set 13 | ndele
# Processing Record 45 of Set 13 | vanavara
# Processing Record 46 of Set 13 | xiaoweizhai
# Processing Record 47 of Set 13 | lagos
# Processing Record 48 of Set 13 | vestmanna
# Processing Record 49 of Set 13 | minab
# Processing Record 50 of Set 13 | mechetinskaya
# Processing Record 1 of Set 14 | morondava
# Processing Record 2 of Set 14 | bima
# Processing Record 3 of Set 14 | riga
# Processing Record 4 of Set 14 | kelapa sawit
# Processing Record 5 of Set 14 | hovd
# Processing Record 6 of Set 14 | turukhansk
# Processing Record 7 of Set 14 | burgos
# Processing Record 8 of Set 14 | falavarjan
# Processing Record 9 of Set 14 | mahajanga
# Processing Record 10 of Set 14 | guapi
# Processing Record 11 of Set 14 | zeya
# Processing Record 12 of Set 14 | trinidad
# Processing Record 13 of Set 14 | kytlym
# City not found. Skipping...
# Processing Record 14 of Set 14 | thunder bay
# Processing Record 15 of Set 14 | lakhipur
# Processing Record 16 of Set 14 | chingirlau
# Processing Record 17 of Set 14 | pacific grove
# Processing Record 18 of Set 14 | horni jiretin
# Processing Record 19 of Set 14 | antofagasta
# Processing Record 20 of Set 14 | balsas
# Processing Record 21 of Set 14 | ennis
# Processing Record 22 of Set 14 | northam
# Processing Record 23 of Set 14 | mocuba
# Processing Record 24 of Set 14 | margate
# Processing Record 25 of Set 14 | seoul
# Processing Record 26 of Set 14 | havoysund
# Processing Record 27 of Set 14 | natitingou
# Processing Record 28 of Set 14 | bad schwartau
# Processing Record 29 of Set 14 | burkhala
# City not found. Skipping...
# Processing Record 30 of Set 14 | uyuni
# Processing Record 31 of Set 14 | orlik
# Processing Record 32 of Set 14 | seydi
# Processing Record 33 of Set 14 | kaura namoda
# Processing Record 34 of Set 14 | yoichi
# Processing Record 35 of Set 14 | san felipe
# Processing Record 36 of Set 14 | saint-quentin
# Processing Record 37 of Set 14 | cururupu
# Processing Record 38 of Set 14 | pyu
# Processing Record 39 of Set 14 | westport
# Processing Record 40 of Set 14 | monrovia
# Processing Record 41 of Set 14 | athens
# Processing Record 42 of Set 14 | elliot lake
# Processing Record 43 of Set 14 | kisangani
# Processing Record 44 of Set 14 | te anau
# Processing Record 45 of Set 14 | mercedes
# Processing Record 46 of Set 14 | gurskoye
# City not found. Skipping...
# Processing Record 47 of Set 14 | uthal
# Processing Record 48 of Set 14 | kaspiyskiy
# Processing Record 49 of Set 14 | ayan
# Processing Record 50 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 1 of Set 15 | helong
# Processing Record 2 of Set 15 | newport
# Processing Record 3 of Set 15 | kulhudhuffushi
# Processing Record 4 of Set 15 | okhotsk
# Processing Record 5 of Set 15 | alofi
# Processing Record 6 of Set 15 | rosarito
# Processing Record 7 of Set 15 | ladario
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 648

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Ushuaia -54.8000  -68.3000     53.26        43          75        8.05
# 1    Roebourne -20.7833  117.1333     82.89        40          13       18.16
# 2  Yellowknife  62.4560 -114.3525      5.56        92          75        4.61
# 3        Vaini -21.2000 -175.2000     78.96        83          75        3.44
# 4       Pombal  -6.7703  -37.8017     79.79        61          38       13.53
# 5      Rikitea -23.1203 -134.9692     73.76        91         100       22.32
# 6    Grindavik  63.8424  -22.4338     46.87        87          75       17.27
# 7     Valencia  39.3333   -0.8333     65.61        77          97       24.81
# 8      Copiapo -27.3667  -70.3333     56.89        69           0        1.01
# 9        Mecca  21.4267   39.8261     76.71        72          69        3.18
#
#   Country   Current Description
# 0      AR         broken clouds
# 1      AU            few clouds
# 2      CA            light snow
# 3      TO         broken clouds
# 4      BR      scattered clouds
# 5      PF  heavy intensity rain
# 6      IS         broken clouds
# 7      ES       overcast clouds
# 8      CL             clear sky
# 9      SA         broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
city_data_new = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description'] 

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[city_data_new]

# Display sample data
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Ushuaia      AR -54.8000  -68.3000     53.26        43          75
# 1    Roebourne      AU -20.7833  117.1333     82.89        40          13
# 2  Yellowknife      CA  62.4560 -114.3525      5.56        92          75
# 3        Vaini      TO -21.2000 -175.2000     78.96        83          75
# 4       Pombal      BR  -6.7703  -37.8017     79.79        61          38
# 5      Rikitea      PF -23.1203 -134.9692     73.76        91         100
# 6    Grindavik      IS  63.8424  -22.4338     46.87        87          75
# 7     Valencia      ES  39.3333   -0.8333     65.61        77          97
# 8      Copiapo      CL -27.3667  -70.3333     56.89        69           0
# 9        Mecca      SA  21.4267   39.8261     76.71        72          69
#
#    Wind Speed   Current Description
# 0        8.05         broken clouds
# 1       18.16            few clouds
# 2        4.61            light snow
# 3        3.44         broken clouds
# 4       13.53      scattered clouds
# 5       22.32  heavy intensity rain
# 6       17.27         broken clouds
# 7       24.81       overcast clouds
# 8        1.01             clear sky
# 9        3.18         broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
